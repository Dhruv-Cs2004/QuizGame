# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhruv-Cs2004/QuizGame/blob/master/Hospital_Project_For_Git.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import time

def Appointment():
    Appoint=open('Doctor_Appontment.txt','r')
    Appoint1=Appoint.read()
    print(Appoint1)
    Appoint.close()

def important():
    important=open('important.txt','r')
    important1=important.read()
    print(important1)
    important.close()

def Sataf():
    timeingnew = time.strftime("\t%m/%d/%Y, %H:%M:%S")
    importantnews = open('important.txt', 'a')
    datainput=input('\t-----------Enter The news For Doctor------------\n')
    importantnews.writelines('\t')
    importantnews.writelines(timeingnew)
    importantnews.writelines('\t\n')
    importantnews.writelines(datainput)
    importantnews.writelines('\n')
    importantnews.close()

def emergency_call():
    for i in range(100):
        print('Hospital Emergency Ambulance No(9567397835)')
        book=int(input('1. Ambulance Booking Through App\n2.exit\nEnter your input:-'))
        if book==1:
            print('\t----------🚑Booking Ambulance🚑----------')
            emer=open('ambluance_book.txt','a')
            name=input('Enter Your Name:-')
            age=input('Enter your age:-')
            adress=input('Enter Your Current Location:-')
            condition=input('Enter the Patient condition:-')
            emer.writelines('\n')
            emer.writelines(name)
            emer.writelines('\t\t')
            emer.writelines(age)
            emer.writelines('\t\t')
            emer.writelines(adress)
            emer.writelines('\t\t')
            emer.writelines(condition)
            print('Ambulance wil arive in 15 Min')
            break
        elif book==2:
            break
        else:
            print('Wrong input')
def emergency_room():
    print('\t----------Emergency Room Booking----------')
    room=open('EmergencyRoom.txt','a')
    timeingnew = time.strftime("%m/%d/%Y %H:%M:%S")
    name=input('Enter Your Name:-')
    age=input('Enter your age:-')
    adress=input('Enter Your Current Location:-')
    condition=input('Enter the Patient condition:-')
    room.writelines('\n')
    room.writelines(timeingnew)
    room.writelines('\t\t')
    room.writelines(name)
    room.writelines('\t\t')
    room.writelines(age)
    room.writelines('\t\t')
    room.writelines(adress)
    room.writelines('\t\t')
    room.writelines(condition)

print('\t\t🏥 welcome to One Life 🏥\n')
a=int(input('1. For Doctor \n2. For New Appointment \n3. Add import news for doctor(Staff)\n4. Patient Details\n5. Emergency services\nEnter your input:-'))
match a:

    case 1:
        user=('Dhruv Sapra')
        Pass=('Dhruv@123')
        for i in range(10):
            user1=input('Enter your user name:-')
            if(user1==user):
                Pass1=input('Enter your Password:-')
                if(Pass1==Pass):
                    for j in range(100):
                        data=int(input('1. Enter to Check Todays Appointment Press\n2. Todays important\n3. billin\n4. to Exit\nEnter your input:-'))
                        if(data==1):
                            Appointment()
                        elif(data==2):
                            important()
                        elif(data==3):
                            info=int(input('Enter Your Uid:-'))
                            getout=open('Doctor_Appontment.txt', 'r')
                            for i in getout:
                                if info==int(getout.readline(9)):
                                    print(getout.readline())
                                    break
                        elif(data==4):
                            break
                else:
                    print('You Enter the wrong password')
                    break
            else:
                print('Wrong User Name')
                break

    case 2:
        print('\t-----------New Appointment------------')
        timeingnew = time.strftime("%m/%d/%Y %H:%M:%S")
        unid=str(random.randint(999999,9999999))
        name=input('Enter your Name:-')
        age=input('Enter yor age:-')
        adress=input('enter Your Adress:-')
        Phoneno=(input('Enter your PhoneNo:-'))
        Problem=(input('Enter your Problem:-'))
        Appointnew = open('Doctor_Appontment.txt', 'a')
        Appointnew.writelines('\n')
        Appointnew.writelines(unid)
        Appointnew.writelines('\t\t')
        Appointnew.writelines(name)
        Appointnew.writelines('\t\t')
        Appointnew.writelines(adress)
        Appointnew.writelines('\t\t')
        Appointnew.writelines(age)
        Appointnew.writelines('\t\t')
        Appointnew.writelines(Phoneno)
        Appointnew.writelines('\t\t')
        Appointnew.writelines(Problem)
        Appointnew.writelines('\t\t')
        Appointnew.writelines(timeingnew)
        print('Yor Id is',unid,'PLZ Note it For Future Identification')
        Appointnew.close()
        print('\t------------Appointment Fixed------------')

    case 3:
        stafuser=('Naman')
        Staffpas=('Naman@2005')
        for k in range(10):
            stafuser1=input('Enter your User Name:-')
            if(stafuser1==stafuser):
                Staffpas1=input('Enter Your PassWord:-')
                if(Staffpas1==Staffpas):
                    Sataf()
                    break
                else:
                    print('You Enter the Wrong Passwor')
            else:
                print('You Enter The Wrong User Name')

    case 4:
        pa=int(input('Enter Your Uid:-'))
        get=open('Doctor_Appontment.txt', 'r')
        for i in get:
            if pa==int(get.readline(7)):
                print(get.readline())
                break

    case 5:
        print('\t-------🆘🚑Hospital Imergincy Services🚑🆘------')
        ser=int(input('1. For Emergency contacts And Booking\n2. Exit\nEnter your input:-'))
        for i in range(100):
            if ser==1:
                im=int(input('1. ambulance and Booking\n2. Hospita emergency Room\nEnter your Input:-'))
                if im==1:
                    emergency_call()
                elif im==2:
                    emergency_room()
                else:
                    print('wrong input')
                    break
            elif ser==2:
                break
            else:
                print('Wrong input')
                break
# Out:
# 		🏥 welcome to One Life 🏥
#
# 1. For Doctor
# 2. For New Appointment
# 3. Add import news for doctor(Staff)
# 4. Patient Details
# 5. Emergency services
# Enter your input:-3
# Enter your User Name:-Dhruv Sapra
# You Enter The Wrong User Name
